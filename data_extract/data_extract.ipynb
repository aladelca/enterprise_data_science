# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd
import re
import numpy as np
import time
import warnings 
warnings.filterwarnings('ignore')

# %%
pd.read_csv('https://raw.githubusercontent.com/youlasozen/Predicting-the-Market-Value-of-Footballers/main/CSV%20Obtained%20from%20Web/newdf.csv')
# Out:
#                    name  Age  Overall rating  Potential      ID  Height  \
# 0            J. Todibo    22              79         84  245388     190
# 1        B. Verbruggen    19              73         83  258498     194
# 2           M. Ugarte     21              79         85  253306     182
# 3            Z. Debast    18              70         84  254262     189
# 4           07 D. Last    37              61         60   21555     182
# ...                 ...  ...             ...        ...     ...     ...
# 2697   D. Mihailovic      23              76         81  237496     178
# 2698        G. Togni      24              70         71  237512     180
# 2699        M. Camara     25              75         77  237520     182
# 2700           S. Kaba    27              69         69  237524     191
# 2701  20 T. Ephestion     24              64         71  237551     189
#
#       Weight   foot  Best overall Best position  ...  Total stats  Base stats  \
# 0         88  Right            81            CB  ...         1852         409
# 1         89  Right            73            GK  ...         1127         412
# 2         77  Right            80           CDM  ...         1950         433
# 3         76  Right            72           CDM  ...         1805         395
# 4         82  Right            61            GK  ...          939         356
# ...      ...    ...           ...           ...  ...          ...         ...
# 2697      69  Right            78           CAM  ...         1974         422
# 2698      76   Left            70            LM  ...         1907         411
# 2699      80  Right            78           CDM  ...         2098         452
# 2700      80  Right            69            ST  ...         1704         367
# 2701      87   Left            65            CM  ...         1683         374
#
#       International reputation  Pace / Diving  Shooting / Handling  \
# 0                            1             75                   47
# 1                            1             75                   70
# 2                            1             72                   63
# 3                            1             67                   53
# 4                            3             63                   55
# ...                        ...            ...                  ...
# 2697                         1             72                   70
# 2698                         1             77                   66
# 2699                         1             76                   74
# 2700                         1             63                   67
# 2701                         1             63                   54
#
#       Passing / Kicking  Dribbling / Reflexes  Defending / Pace  \
# 0                    63                    67                80
# 1                    71                    76                52
# 2                    71                    77                75
# 3                    67                    67                69
# 4                    63                    60                45
# ...                 ...                   ...               ...
# 2697                 76                    76                60
# 2698                 65                    71                63
# 2699                 73                    74                74
# 2700                 59                    67                31
# 2701                 61                    63                59
#
#                     team              contract
# 0                   Nice           2021 ~ 2027
# 1             Anderlecht           2020 ~ 2025
# 2            Sporting CP           2021 ~ 2026
# 3             Anderlecht           2019 ~ 2025
# 4                Örgryte                  2009
# ...                  ...                   ...
# 2697                  AZ           2023 ~ 2027
# 2698  Defensa y Justicia  Dec 31, 2023 On loan
# 2699                Roma           2018 ~ 2024
# 2700        Cardiff City  Jun 30, 2023 On loan
# 2701             Orléans           2018 ~ 2021
#
# [2702 rows x 65 columns]
